# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# Continuous plots 
df = pd.read_excel('qap_ga_100.xlsx')
df.head()
# Out:
#    Generation  0_100_50_0.1  0_100_100_0.1  0_100_300_0.1  0_100_50_0.4  \
# 0           0          1422           1422           1356          1422
# 1           1          1422           1386           1356          1422
# 2           2          1376           1372           1330          1392
# 3           3          1376           1372           1330          1392
# 4           4          1376           1372           1330          1360
#
#    0_100_100_0.4  0_100_300_0.4  0_100_50_0.6  0_100_100_0.6  0_100_300_0.6  \
# 0           1422           1356          1422           1422           1356
# 1           1422           1356          1406           1422           1338
# 2           1316           1356          1406           1396           1338
# 3           1316           1310          1386           1374           1338
# 4           1316           1310          1374           1374           1338
#
#    ...  7_100_300_0.6  8_100_50_0.1  8_100_100_0.1  8_100_300_0.1  \
# ...

# %%
seed_exp = [i for i in range(9)]
pbb_mutation_exp = [0.1, 0.4, 0.6]
population_size_exp = [50, 100, 300]
max_generation_exp = [100, 500, 1000]

seed_exp = [i for i in range(9)]
pbb_mutation_exp = [0.4]
population_size_exp = [100]

# %%
seed_exp = [i for i in range(9)]
pbb_mutation_exp = [0.4]
population_size_exp = [100]
for pop_size_it in population_size_exp:
    for pbb_it in pbb_mutation_exp:
        plt.figure(figsize=(8, 6))
        for seed_it in seed_exp: 
            plt.plot(df['Generation'], 
                     df[f'{seed_it}_100_{pop_size_it}_{pbb_it}'], label=f'Seed {seed_it}')

        plt.xlabel('Generations')
        plt.ylabel('Objective function')
        plt.legend(loc=1, title='Instances')
        #plt.savefig(f'qap_initial_solution_effect.pdf');
        #plt.show()

# %%
# Effect of the probability 
gen_size = 500
df = pd.read_excel(f'qap_ga_{gen_size}.xlsx')
seed_exp = [5]
pbb_mutation_exp = [0.1, 0.4, 0.6]
population_size_exp = [100]

for pop_size_it in population_size_exp:
    for seed_it in seed_exp:
        plt.figure(figsize=(8, 6))
        for pbb_it in pbb_mutation_exp:
            plt.plot(df['Generation'],df[f'{seed_it}_{gen_size}_{pop_size_it}_{pbb_it}'], label=f'$P_m = {pbb_it}$')
        
        plt.xlabel('Generations')
        plt.ylabel('Objective function')
        plt.legend(loc=1, title='Mutation Probability')
        plt.savefig(f'qap_pbb_effect_{seed_it}.pdf');
        #plt.show()

# %%
# Effect of the gen size
gen_size = 1000
df = pd.read_excel(f'qap_ga_{gen_size}.xlsx')
seed_exp = [4]
pbb_mutation_exp = [0.4]
population_size_exp = [50, 100, 300]

for seed_it in seed_exp:
    for pbb_it in pbb_mutation_exp:
        plt.figure(figsize=(8, 6))
        for pop_size_it in population_size_exp:
            plt.plot(df['Generation'],df[f'{seed_it}_{gen_size}_{pop_size_it}_{pbb_it}'], label=f'{pop_size_it}')
        
        plt.xlabel('Generations')
        plt.ylabel('Objective function')
        plt.legend(loc=1, title='Population size')
        plt.savefig(f'qap_gensize_effect_{seed_it}.pdf');
        #plt.show()

# %%
# Effect of the gen size
gen_size = 1000
df = pd.read_excel(f'qap_ga_{gen_size}.xlsx')
seed_exp = [4]
pbb_mutation_exp = [0.4]
population_size_exp = [50, 100, 300]

for seed_it in seed_exp:
    for pbb_it in pbb_mutation_exp:
        plt.figure(figsize=(8, 6))
        for pop_size_it in population_size_exp:
            plt.plot(df['Generation'],df[f'{seed_it}_{gen_size}_{pop_size_it}_{pbb_it}'], label=f'{pop_size_it}')
        
        plt.xlabel('Generations')
        plt.ylabel('Objective function')
        plt.legend(loc=1, title='Population size')
        plt.savefig(f'qap_gensize_effect_{seed_it}.pdf');
        #plt.show()

# %%
# Effect of the initial solution
df = pd.read_excel('qap_ga_100.xlsx')
seed_exp = [i for i in range(9)]
pbb_mutation_exp = [0.4]
population_size_exp = [100]
for pop_size_it in population_size_exp:
    for pbb_it in pbb_mutation_exp:
        plt.figure(figsize=(8, 6))
        for seed_it in seed_exp: 
            plt.plot(df['Generation'], 
                     df[f'{seed_it}_100_{pop_size_it}_{pbb_it}'], label=f'Set {seed_it}')

        plt.xlabel('Generations')
        plt.ylabel('Objective function')
        plt.legend(loc=1, title='Instances')
        plt.savefig(f'qap_initial_solution_effect.pdf');
        #plt.show()

# %% [markdown]
# # Combinatorial problem plots

# %%
# Out:
# '8.415844474970001, -4.035190615835777, 4.09775171065494'

# %%
seed_exp = [i for i in range(9)]
pbb_mutation_exp = [0.1, 0.25, 0.6]
population_size_exp = [10, 40, 100]
max_generation_exp = [100, 500, 1000]

# %%
df = pd.read_excel(f'continuous_ga_100.xlsx')
seed_exp = [i for i in range(9)]
pbb_mutation_exp = [0.1]
population_size_exp = [10]
for pop_size_it in population_size_exp:
    for pbb_it in pbb_mutation_exp:
        plt.figure(figsize=(8, 6))
        for seed_it in seed_exp: 
            plt.plot(df['Generation'], 
                     df[f'{seed_it}_100_{pop_size_it}_{pbb_it}'], label=f'Set {seed_it}')

        plt.xlabel('Generations')
        plt.ylabel('Objective function')
        plt.legend(loc=1, title='Instances')
        plt.savefig(f'cont_initial_solution_effect.pdf');
        #plt.show()

# %%
# Effect of the probability 
gen_size = 100
df = pd.read_excel(f'continuous_ga_{gen_size}.xlsx')
seed_exp = [4]
pbb_mutation_exp = [0.1, 0.25, 0.6]
population_size_exp = [100]

for pop_size_it in population_size_exp:
    for seed_it in seed_exp:
        plt.figure(figsize=(8, 6))
        for pbb_it in pbb_mutation_exp:
            plt.plot(df['Generation'],df[f'{seed_it}_{gen_size}_{pop_size_it}_{pbb_it}'], label=f'$P_m = {pbb_it}$')
        
        plt.xlabel('Generations')
        plt.ylabel('Objective function')
        plt.legend(loc=1, title='Mutation Probability')
        plt.savefig(f'cont_pbb_effect_{seed_it}.pdf');
        #plt.show()

# %%
# Effect of the gen size
gen_size = 100
df = pd.read_excel(f'continuous_ga_{gen_size}.xlsx')
seed_exp = [4]
pbb_mutation_exp = [0.25]
population_size_exp = [10, 40, 100]

for seed_it in seed_exp:
    for pbb_it in pbb_mutation_exp:
        plt.figure(figsize=(8, 6))
        for pop_size_it in population_size_exp:
            plt.plot(df['Generation'],df[f'{seed_it}_{gen_size}_{pop_size_it}_{pbb_it}'], label=f'{pop_size_it}')
        
        plt.xlabel('Generations')
        plt.ylabel('Objective function')
        plt.legend(loc=1, title='Population size')
        plt.savefig(f'cont_gensize_effect_{seed_it}.pdf');
        #plt.show()

# %%
exp_seeds = [0, 3, 5, 7, 10]
exp_temp = [100, 500, 1000]
exp_stops = [1000, 5000, 10000]

# %%
for it_temp in exp_temp:
    for it_stops in exp_stops:
        plt.figure(figsize=(8, 6))
        for it_seed in exp_seeds:
            df = pd.read_excel(f'results_qap/exp_{it_seed}_{it_temp}_{it_stops}.xlsx')
            plt.plot(df['temp'], df['cost'], label=f'Seed {it_seed}')
        plt.xlim(max(df['temp']), 0)
        plt.xlabel('Temperature')
        plt.ylabel('Objective function')
        plt.legend(loc=1, title='Instances')
        plt.savefig(f'plots_comb/{it_temp}_{it_stops}.pdf');
        #plt.show()

# %%
for it_seed in exp_seeds:
    for it_stops in exp_stops:
        plt.figure(figsize=(8, 6))
        for it_temp in exp_temp:
            df = pd.read_excel(f'results_qap/exp_{it_seed}_{it_temp}_{it_stops}.xlsx')
            plt.plot(df['cost'], label=f'Temperature  {it_temp}')
        plt.xlabel('Iterations')
        plt.ylabel('Objective function')
        plt.legend(loc=1, title='Instances')
        plt.savefig(f'plots_comb/cost_{it_seed}_{it_stops}.pdf');
        #plt.show()

# %%
df = pd.read_excel(f'results_qap/exp_0_100_1000.xlsx')
plt.plot(df['cost'], label=f'Temperature  100')

# %%
df = pd.read_excel(f'results_qap/exp_0_1000_1000.xlsx')
plt.plot(df['cost'], label=f'Temperature  100')
